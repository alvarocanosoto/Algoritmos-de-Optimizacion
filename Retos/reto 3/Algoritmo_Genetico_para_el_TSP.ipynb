# %% [markdown]
# # Algoritmos de optimización - Reto 3
#
# Nombre: Álvaro Caño Soto<br>
# Github: https://github.com/alvarocanosoto/Algoritmos-de-Optimizacion/tree/main/Retos <br>

# %%
# !pip install requests
import urllib.request

# !pip install tsplib95
import tsplib95
# Out:
# Requirement already satisfied: requests in c:\users\alvaro\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alvaro\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alvaro\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alvaro\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alvaro\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: tsplib95 in c:\users\alvaro\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: Click>=6.0 in c:\users\alvaro\anaconda3\lib\site-packages (from tsplib95) (8.1.7)
# Requirement already satisfied: Deprecated~=1.2.9 in c:\users\alvaro\anaconda3\lib\site-packages (from tsplib95) (1.2.18)
# Requirement already satisfied: networkx~=2.1 in c:\users\alvaro\anaconda3\lib\site-packages (from tsplib95) (2.8.8)
# Requirement already satisfied: tabulate~=0.8.7 in c:\users\alvaro\anaconda3\lib\site-packages (from tsplib95) (0.8.10)
# Requirement already satisfied: colorama in c:\users\alvaro\anaconda3\lib\site-packages (from Click>=6.0->tsplib95) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\alvaro\anaconda3\lib\site-packages (from Deprecated~=1.2.9->tsplib95) (1.14.1)

# %%
import random   #Libreria para generar numeros y listas aleatorias
import copy     #Permite hacer copias de objetos en python: listas, diccionarios,...

# %%
#Librerias y carga del problema

#http://elib.zib.de/pub/mp-testdata/tsp/tsplib/
#Documentacion :
  # https://wwwproxy.iwr.uni-heidelberg.de/groups/comopt/software/TSPLIB95/tsp95.pdf
  # https://tsplib95.readthedocs.io/usage.html
  # https://tsplib95.readthedocs.io/modules.html#module-tsplib95.models

#Descargamos el fichero de datos(Matriz de distancias)
file = "swiss42.tsp"
# urllib.request.urlretrieve("http://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/tsp/swiss42.tsp.gz", file + '.gz')

#Objeto de tsplib95 para nuestro problema problema
problem = tsplib95.load(file)

#Nodos
Nodos = list(problem.get_nodes())

#Aristas
Aristas = list(problem.get_edges())

#Coordenadas(si estan disponibles en el ficher)
problem.get_display(1)

#Distancia
problem.get_weight(1, 2)

#Matriz de distancias
[ [problem.get_weight(i, j)   for i in  list(problem.get_nodes()) ]  for j in  list(problem.get_nodes()) ]
# Out:
# [[0,
#   15,
#   30,
#   23,
#   32,
#   55,
#   33,
#   37,
#   92,
#   114,
#   92,
#   110,
#   96,
#   90,
#   74,
#   76,
#   82,
#   67,
#   72,
#   78,
#   82,
#   159,
#   122,
#   131,
#   206,
#   112,
#   57,
#   28,
#   43,
#   70,
#   65,
#   66,
#   37,
#   103,
#   84,
#   125,
#   129,
#   72,
#   126,
#   141,
#   183,
#   124],
#  [15,
#   0,
#   34,
#   23,
#   27,
#   40,
#   19,
#   32,
#   93,
#   117,
#   88,
#   100,
#   87,
#   75,
#   63,
#   67,
#   71,
#   69,
#   62,
#   63,
#   96,
#   164,
#   132,
#   131,
#   212,
#   106,
#   44,
#   33,
#   51,
#   77,
#   75,
#   72,
#   52,
#   118,
#   99,
#   132,
#   132,
#   67,
#   139,
#   148,
#   186,
#   122],
#  [30,
#   34,
#   0,
#   11,
#   18,
#   57,
#   36,
#   65,
#   62,
#   84,
#   64,
#   89,
#   76,
#   93,
#   95,
#   100,
#   104,
#   98,
#   57,
#   88,
#   99,
#   130,
#   100,
#   101,
#   179,
#   86,
#   51,
#   4,
#   18,
#   43,
#   45,
#   95,
#   45,
#   115,
#   93,
#   152,
#   159,
#   100,
#   112,
#   114,
#   153,
#   94],
#  [23,
#   23,
#   11,
#   0,
#   11,
#   48,
#   26,
#   54,
#   70,
#   94,
#   69,
#   89,
#   75,
#   84,
#   84,
#   89,
#   92,
#   89,
#   54,
#   78,
#   99,
#   141,
#   111,
#   109,
#   190,
#   89,
#   44,
#   11,
#   29,
#   54,
#   56,
#   89,
#   47,
#   118,
#   96,
#   147,
#   151,
#   90,
#   122,
#   126,
#   163,
#   101],
#  [32,
#   27,
#   18,
#   11,
#   0,
#   40,
#   20,
#   58,
#   67,
#   92,
#   61,
#   78,
#   65,
#   76,
#   83,
#   89,
#   91,
#   95,
#   43,
#   72,
#   110,
#   141,
#   116,
#   105,
#   190,
#   81,
#   34,
#   19,
#   35,
#   57,
#   63,
#   97,
#   58,
#   129,
#   107,
#   156,
#   158,
#   92,
#   129,
#   127,
#   161,
#   95],
#  [55,
#   40,
#   57,
#   48,
#   40,
#   0,
#   23,
#   55,
#   96,
#   123,
#   78,
#   75,
#   62,
#   36,
#   56,
#   66,
#   63,
#   95,
#   37,
#   34,
#   137,
#   174,
#   156,
#   129,
#   224,
#   90,
#   15,
#   59,
#   75,
#   96,
#   103,
#   105,
#   91,
#   158,
#   139,
#   164,
#   156,
#   78,
#   169,
#   163,
#   191,
#   115],
#  [33,
#   19,
#   36,
#   26,
#   20,
#   23,
#   0,
#   45,
#   85,
#   111,
#   75,
#   82,
#   69,
#   60,
#   63,
#   70,
#   71,
#   85,
#   44,
#   52,
#   115,
#   161,
#   136,
#   122,
#   210,
#   91,
#   25,
#   37,
#   54,
#   78,
#   81,
#   90,
#   68,
#   136,
#   116,
#   150,
#   147,
#   76,
#   148,
#   147,
#   180,
#   111],
#  [37,
#   32,
#   65,
#   54,
#   58,
#   55,
#   45,
#   0,
#   124,
#   149,
#   118,
#   126,
#   113,
#   80,
#   42,
#   42,
#   49,
#   40,
#   87,
#   60,
#   94,
#   195,
#   158,
#   163,
#   242,
#   135,
#   65,
#   63,
#   79,
#   106,
#   101,
#   50,
#   66,
#   118,
#   104,
#   109,
#   103,
#   36,
#   160,
#   178,
#   218,
#   153],
#  [92,
#   93,
#   62,
#   70,
#   67,
#   96,
#   85,
#   124,
#   0,
#   28,
#   29,
#   68,
#   63,
#   122,
#   148,
#   155,
#   156,
#   159,
#   67,
#   129,
#   148,
#   78,
#   80,
#   39,
#   129,
#   46,
#   82,
#   65,
#   55,
#   40,
#   61,
#   157,
#   97,
#   159,
#   135,
#   212,
#   221,
#   159,
#   110,
#   72,
#   95,
#   35],
#  [114,
#   117,
#   84,
#   94,
#   92,
#   123,
#   111,
#   149,
#   28,
#   0,
#   54,
#   91,
#   88,
#   150,
#   174,
#   181,
#   182,
#   181,
#   95,
#   157,
#   159,
#   50,
#   65,
#   27,
#   102,
#   65,
#   110,
#   87,
#   73,
#   50,
#   68,
#   176,
#   112,
#   166,
#   142,
#   229,
#   241,
#   184,
#   99,
#   46,
#   69,
#   38],
#  [92,
#   88,
#   64,
#   69,
#   61,
#   78,
#   75,
#   118,
#   29,
#   54,
#   0,
#   39,
#   34,
#   99,
#   134,
#   142,
#   141,
#   157,
#   44,
#   110,
#   161,
#   103,
#   109,
#   52,
#   154,
#   22,
#   63,
#   68,
#   66,
#   61,
#   81,
#   158,
#   107,
#   175,
#   151,
#   216,
#   219,
#   150,
#   137,
#   100,
#   115,
#   37],
#  [110,
#   100,
#   89,
#   89,
#   78,
#   75,
#   82,
#   126,
#   68,
#   91,
#   39,
#   0,
#   14,
#   80,
#   129,
#   139,
#   135,
#   167,
#   39,
#   98,
#   187,
#   136,
#   148,
#   81,
#   186,
#   28,
#   61,
#   92,
#   97,
#   98,
#   117,
#   173,
#   134,
#   204,
#   181,
#   232,
#   229,
#   153,
#   176,
#   137,
#   143,
#   62],
#  [96,
#   87,
#   76,
#   75,
#   65,
#   62,
#   69,
#   113,
#   63,
#   88,
#   34,
#   14,
#   0,
#   72,
#   117,
#   128,
#   124,
#   153,
#   26,
#   88,
#   174,
#   136,
#   142,
#   82,
#   187,
#   32,
#   48,
#   79,
#   85,
#   89,
#   106,
#   159,
#   121,
#   191,
#   168,
#   219,
#   216,
#   140,
#   168,
#   134,
#   145,
#   64],
#  [90,
#   75,
#   93,
#   84,
#   76,
#   36,
#   60,
#   80,
#   122,
#   150,
#   99,
#   80,
#   72,
#   0,
#   59,
#   71,
#   63,
#   116,
#   56,
#   25,
#   170,
#   201,
#   189,
#   151,
#   252,
#   104,
#   44,
#   95,
#   111,
#   130,
#   138,
#   130,
#   127,
#   192,
#   174,
#   186,
#   172,
#   90,
#   205,
#   193,
#   214,
#   135],
#  [74,
#   63,
#   95,
#   84,
#   83,
#   56,
#   63,
#   42,
#   148,
#   174,
#   134,
#   129,
#   117,
#   59,
#   0,
#   11,
#   8,
#   63,
#   93,
#   35,
#   135,
#   223,
#   195,
#   184,
#   273,
#   146,
#   71,
#   95,
#   113,
#   138,
#   138,
#   81,
#   107,
#   159,
#   146,
#   132,
#   113,
#   32,
#   200,
#   209,
#   243,
#   171],
#  [76,
#   67,
#   100,
#   89,
#   89,
#   66,
#   70,
#   42,
#   155,
#   181,
#   142,
#   139,
#   128,
#   71,
#   11,
#   0,
#   11,
#   54,
#   103,
#   46,
#   130,
#   230,
#   198,
#   192,
#   279,
#   155,
#   80,
#   99,
#   117,
#   143,
#   141,
#   74,
#   107,
#   155,
#   143,
#   122,
#   102,
#   22,
#   202,
#   215,
#   250,
#   179],
#  [82,
#   71,
#   104,
#   92,
#   91,
#   63,
#   71,
#   49,
#   156,
#   182,
#   141,
#   135,
#   124,
#   63,
#   8,
#   11,
#   0,
#   65,
#   100,
#   39,
#   140,
#   232,
#   203,
#   192,
#   281,
#   153,
#   78,
#   103,
#   121,
#   147,
#   146,
#   85,
#   115,
#   164,
#   152,
#   133,
#   112,
#   33,
#   208,
#   218,
#   251,
#   178],
#  [67,
#   69,
#   98,
#   89,
#   95,
#   95,
#   85,
#   40,
#   159,
#   181,
#   157,
#   167,
#   153,
#   116,
#   63,
#   54,
#   65,
#   0,
#   127,
#   92,
#   83,
#   224,
#   180,
#   199,
#   269,
#   175,
#   106,
#   95,
#   109,
#   135,
#   125,
#   21,
#   80,
#   107,
#   100,
#   71,
#   63,
#   33,
#   173,
#   205,
#   249,
#   191],
#  [72,
#   62,
#   57,
#   54,
#   43,
#   37,
#   44,
#   87,
#   67,
#   95,
#   44,
#   39,
#   26,
#   56,
#   93,
#   103,
#   100,
#   127,
#   0,
#   67,
#   153,
#   145,
#   139,
#   96,
#   196,
#   53,
#   23,
#   60,
#   70,
#   81,
#   95,
#   134,
#   101,
#   172,
#   149,
#   194,
#   190,
#   115,
#   160,
#   138,
#   159,
#   80],
#  [78,
#   63,
#   88,
#   78,
#   72,
#   34,
#   52,
#   60,
#   129,
#   157,
#   110,
#   98,
#   88,
#   25,
#   35,
#   46,
#   39,
#   92,
#   67,
#   0,
#   152,
#   207,
#   188,
#   162,
#   258,
#   119,
#   48,
#   89,
#   107,
#   129,
#   134,
#   108,
#   114,
#   176,
#   159,
#   163,
#   147,
#   66,
#   200,
#   197,
#   224,
#   147],
#  [82,
#   96,
#   99,
#   99,
#   110,
#   137,
#   115,
#   94,
#   148,
#   159,
#   161,
#   187,
#   174,
#   170,
#   135,
#   130,
#   140,
#   83,
#   153,
#   152,
#   0,
#   188,
#   128,
#   184,
#   222,
#   183,
#   139,
#   95,
#   95,
#   110,
#   91,
#   62,
#   54,
#   24,
#   23,
#   81,
#   110,
#   113,
#   108,
#   164,
#   217,
#   184],
#  [159,
#   164,
#   130,
#   141,
#   141,
#   174,
#   161,
#   195,
#   78,
#   50,
#   103,
#   136,
#   136,
#   201,
#   223,
#   230,
#   232,
#   224,
#   145,
#   207,
#   188,
#   0,
#   65,
#   57,
#   51,
#   109,
#   160,
#   132,
#   116,
#   90,
#   102,
#   217,
#   148,
#   188,
#   168,
#   264,
#   281,
#   231,
#   100,
#   26,
#   30,
#   75],
#  [122,
#   132,
#   100,
#   111,
#   116,
#   156,
#   136,
#   158,
#   80,
#   65,
#   109,
#   148,
#   142,
#   189,
#   195,
#   198,
#   203,
#   180,
#   139,
#   188,
#   128,
#   65,
#   0,
#   91,
#   94,
#   126,
#   145,
#   100,
#   82,
#   60,
#   57,
#   167,
#   99,
#   126,
#   106,
#   208,
#   230,
#   194,
#   36,
#   39,
#   94,
#   103],
#  [131,
#   131,
#   101,
#   109,
#   105,
#   129,
#   122,
#   163,
#   39,
#   27,
#   52,
#   81,
#   82,
#   151,
#   184,
#   192,
#   192,
#   199,
#   96,
#   162,
#   184,
#   57,
#   91,
#   0,
#   106,
#   53,
#   115,
#   104,
#   94,
#   74,
#   94,
#   196,
#   134,
#   192,
#   168,
#   251,
#   260,
#   197,
#   126,
#   64,
#   64,
#   19],
#  [206,
#   212,
#   179,
#   190,
#   190,
#   224,
#   210,
#   242,
#   129,
#   102,
#   154,
#   186,
#   187,
#   252,
#   273,
#   279,
#   281,
#   269,
#   196,
#   258,
#   222,
#   51,
#   94,
#   106,
#   0,
#   158,
#   211,
#   180,
#   163,
#   136,
#   145,
#   259,
#   190,
#   218,
#   200,
#   302,
#   323,
#   278,
#   120,
#   65,
#   49,
#   124],
#  [112,
#   106,
#   86,
#   89,
#   81,
#   90,
#   91,
#   135,
#   46,
#   65,
#   22,
#   28,
#   32,
#   104,
#   146,
#   155,
#   153,
#   175,
#   53,
#   119,
#   183,
#   109,
#   126,
#   53,
#   158,
#   0,
#   75,
#   89,
#   88,
#   83,
#   103,
#   178,
#   129,
#   197,
#   173,
#   236,
#   238,
#   166,
#   156,
#   111,
#   115,
#   34],
#  [57,
#   44,
#   51,
#   44,
#   34,
#   15,
#   25,
#   65,
#   82,
#   110,
#   63,
#   61,
#   48,
#   44,
#   71,
#   80,
#   78,
#   106,
#   23,
#   48,
#   139,
#   160,
#   145,
#   115,
#   211,
#   75,
#   0,
#   53,
#   68,
#   86,
#   95,
#   114,
#   90,
#   160,
#   139,
#   173,
#   168,
#   92,
#   162,
#   150,
#   176,
#   101],
#  [28,
#   33,
#   4,
#   11,
#   19,
#   59,
#   37,
#   63,
#   65,
#   87,
#   68,
#   92,
#   79,
#   95,
#   95,
#   99,
#   103,
#   95,
#   60,
#   89,
#   95,
#   132,
#   100,
#   104,
#   180,
#   89,
#   53,
#   0,
#   18,
#   44,
#   45,
#   92,
#   42,
#   112,
#   89,
#   149,
#   156,
#   99,
#   111,
#   116,
#   155,
#   97],
#  [43,
#   51,
#   18,
#   29,
#   35,
#   75,
#   54,
#   79,
#   55,
#   73,
#   66,
#   97,
#   85,
#   111,
#   113,
#   117,
#   121,
#   109,
#   70,
#   107,
#   95,
#   116,
#   82,
#   94,
#   163,
#   88,
#   68,
#   18,
#   0,
#   27,
#   27,
#   103,
#   42,
#   109,
#   85,
#   157,
#   168,
#   115,
#   94,
#   98,
#   140,
#   90],
#  [70,
#   77,
#   43,
#   54,
#   57,
#   96,
#   78,
#   106,
#   40,
#   50,
#   61,
#   98,
#   89,
#   130,
#   138,
#   143,
#   147,
#   135,
#   81,
#   129,
#   110,
#   90,
#   60,
#   74,
#   136,
#   83,
#   86,
#   44,
#   27,
#   0,
#   21,
#   128,
#   62,
#   119,
#   96,
#   179,
#   192,
#   142,
#   79,
#   72,
#   115,
#   74],
#  [65,
#   75,
#   45,
#   56,
#   63,
#   103,
#   81,
#   101,
#   61,
#   68,
#   81,
#   117,
#   106,
#   138,
#   138,
#   141,
#   146,
#   125,
#   95,
#   134,
#   91,
#   102,
#   57,
#   94,
#   145,
#   103,
#   95,
#   45,
#   27,
#   21,
#   0,
#   115,
#   46,
#   98,
#   75,
#   163,
#   179,
#   136,
#   67,
#   81,
#   129,
#   95],
#  [66,
#   72,
#   95,
#   89,
#   97,
#   105,
#   90,
#   50,
#   157,
#   176,
#   158,
#   173,
#   159,
#   130,
#   81,
#   74,
#   85,
#   21,
#   134,
#   108,
#   62,
#   217,
#   167,
#   196,
#   259,
#   178,
#   114,
#   92,
#   103,
#   128,
#   115,
#   0,
#   69,
#   86,
#   81,
#   60,
#   65,
#   54,
#   158,
#   195,
#   243,
#   190],
#  [37,
#   52,
#   45,
#   47,
#   58,
#   91,
#   68,
#   66,
#   97,
#   112,
#   107,
#   134,
#   121,
#   127,
#   107,
#   107,
#   115,
#   80,
#   101,
#   114,
#   54,
#   148,
#   99,
#   134,
#   190,
#   129,
#   90,
#   42,
#   42,
#   62,
#   46,
#   69,
#   0,
#   71,
#   49,
#   117,
#   133,
#   98,
#   95,
#   127,
#   175,
#   132],
#  [103,
#   118,
#   115,
#   118,
#   129,
#   158,
#   136,
#   118,
#   159,
#   166,
#   175,
#   204,
#   191,
#   192,
#   159,
#   155,
#   164,
#   107,
#   172,
#   176,
#   24,
#   188,
#   126,
#   192,
#   218,
#   197,
#   160,
#   112,
#   109,
#   119,
#   98,
#   86,
#   71,
#   0,
#   24,
#   94,
#   127,
#   137,
#   100,
#   163,
#   218,
#   194],
#  [84,
#   99,
#   93,
#   96,
#   107,
#   139,
#   116,
#   104,
#   135,
#   142,
#   151,
#   181,
#   168,
#   174,
#   146,
#   143,
#   152,
#   100,
#   149,
#   159,
#   23,
#   168,
#   106,
#   168,
#   200,
#   173,
#   139,
#   89,
#   85,
#   96,
#   75,
#   81,
#   49,
#   24,
#   0,
#   104,
#   133,
#   127,
#   85,
#   143,
#   197,
#   170],
#  [125,
#   132,
#   152,
#   147,
#   156,
#   164,
#   150,
#   109,
#   212,
#   229,
#   216,
#   232,
#   219,
#   186,
#   132,
#   122,
#   133,
#   71,
#   194,
#   163,
#   81,
#   264,
#   208,
#   251,
#   302,
#   236,
#   173,
#   149,
#   157,
#   179,
#   163,
#   60,
#   117,
#   94,
#   104,
#   0,
#   39,
#   100,
#   190,
#   241,
#   292,
#   246],
#  [129,
#   132,
#   159,
#   151,
#   158,
#   156,
#   147,
#   103,
#   221,
#   241,
#   219,
#   229,
#   216,
#   172,
#   113,
#   102,
#   112,
#   63,
#   190,
#   147,
#   110,
#   281,
#   230,
#   260,
#   323,
#   238,
#   168,
#   156,
#   168,
#   192,
#   179,
#   65,
#   133,
#   127,
#   133,
#   39,
#   0,
#   81,
#   216,
#   259,
#   307,
#   253],
#  [72,
#   67,
#   100,
#   90,
#   92,
#   78,
#   76,
#   36,
#   159,
#   184,
#   150,
#   153,
#   140,
#   90,
#   32,
#   22,
#   33,
#   33,
#   115,
#   66,
#   113,
#   231,
#   194,
#   197,
#   278,
#   166,
#   92,
#   99,
#   115,
#   142,
#   136,
#   54,
#   98,
#   137,
#   127,
#   100,
#   81,
#   0,
#   193,
#   214,
#   253,
#   187],
#  [126,
#   139,
#   112,
#   122,
#   129,
#   169,
#   148,
#   160,
#   110,
#   99,
#   137,
#   176,
#   168,
#   205,
#   200,
#   202,
#   208,
#   173,
#   160,
#   200,
#   108,
#   100,
#   36,
#   126,
#   120,
#   156,
#   162,
#   111,
#   94,
#   79,
#   67,
#   158,
#   95,
#   100,
#   85,
#   190,
#   216,
#   193,
#   0,
#   74,
#   129,
#   137],
#  [141,
#   148,
#   114,
#   126,
#   127,
#   163,
#   147,
#   178,
#   72,
#   46,
#   100,
#   137,
#   134,
#   193,
#   209,
#   215,
#   218,
#   205,
#   138,
#   197,
#   164,
#   26,
#   39,
#   64,
#   65,
#   111,
#   150,
#   116,
#   98,
#   72,
#   81,
#   195,
#   127,
#   163,
#   143,
#   241,
#   259,
#   214,
#   74,
#   0,
#   55,
#   80],
#  [183,
#   186,
#   153,
#   163,
#   161,
#   191,
#   180,
#   218,
#   95,
#   69,
#   115,
#   143,
#   145,
#   214,
#   243,
#   250,
#   251,
#   249,
#   159,
#   224,
#   217,
#   30,
#   94,
#   64,
#   49,
#   115,
#   176,
#   155,
#   140,
#   115,
#   129,
#   243,
#   175,
#   218,
#   197,
#   292,
#   307,
#   253,
#   129,
#   55,
#   0,
#   81],
#  [124,
#   122,
#   94,
#   101,
#   95,
#   115,
#   111,
#   153,
#   35,
#   38,
#   37,
#   62,
#   64,
#   135,
#   171,
#   179,
#   178,
#   191,
#   80,
#   147,
#   184,
#   75,
#   103,
#   19,
#   124,
#   34,
#   101,
#   97,
#   90,
#   74,
#   95,
#   190,
#   132,
#   194,
#   170,
#   246,
#   253,
#   187,
#   137,
#   80,
#   81,
#   0]]

# %%
#Funciones de la Actividad Guiada 3
#Se genera una solucion aleatoria con comienzo en en el nodo 0
def crear_solucion(Nodos):
  solucion = [Nodos[0]]
  for n in Nodos[1:] :
    solucion = solucion + [random.choice(list(set(Nodos) - set(solucion)))]
  return solucion

#Devuelve la distancia entre dos nodos
def distancia(a,b, problem):
  return problem.get_weight(a,b)


#Devuelve la distancia total de una trayectoria/solucion
def distancia_total(solucion, problem):
  distancia_total = 0
  for i in range(len(solucion)-1):
    distancia_total += distancia(solucion[i] ,solucion[i+1] ,  problem)
  return distancia_total + distancia(solucion[len(solucion)-1] ,solucion[0], problem)

# %%
distancia_total( [0, 32, 34, 33, 20, 35, 36, 31, 17, 7, 1, 6, 4, 3, 27, 2, 28, 29, 30, 38, 22, 39, 21, 24, 40, 23, 41, 9, 8, 10, 25, 11, 12, 18, 26, 5, 13, 19, 14, 16, 15, 37] , problem)
# Out:
# 1326

# %%
#Genera una poblacion inicial de soluciones de tamaño N
def generar_poblacion(Nodos,N):
  return [crear_solucion(Nodos) for _ in range(N) ]


#Evalua la población y devuelve el mejor individuo
def Evaluar_Poblacion(poblacion, problem):
    mejor_solucion = []
    mejor_distancia = float('inf')
    for p in poblacion:
        distancia_referencia = distancia_total(p, problem)
        if distancia_referencia < mejor_distancia:
            mejor_solucion = p
            mejor_distancia = distancia_referencia
    return mejor_solucion, mejor_distancia

#Funcion de cruce. Recibe una poblacion(lista de soluciones) y devuelve la población ampliada con los hijos.
# Todos los individuos de la población son selecionados para el cruce(si la población es par)
# Podría aplicarse un proceso previo de selección para elegir los individuos que se desea cruzar.
def Cruzar(poblacion,mutacion, problem):
    poblacion_final = copy.deepcopy(poblacion)
    while len(poblacion) > 1:
        padre1, padre2 = random.sample(poblacion, 2)
        poblacion.remove(padre1)
        poblacion.remove(padre2)
        poblacion_final.extend(Descendencia([padre1, padre2], problem, mutacion))
    return poblacion_final

#Funcion para generar hijos a partir de 2 padres:
# Se elige el metodo de 1-punto de corte pero es posible usar otros n-puntos, uniforme, dependiendo del problema
def Descendencia(padres, problem,mutacion):
  #Se elige un punto de corte aleatorio:
  pc = random.sample( range(1,len(padres[0])),1)[0]
  hijo1 =  Factibilizar(padres[0][:pc] + padres[1][pc:] ,problem)
  hijo2 =  Factibilizar(padres[1][:pc] + padres[0][pc:] ,problem)
  return [hijo1,hijo2,Mutar(hijo1,mutacion),Mutar(hijo2,mutacion)]

#Para el operador de cruce 1-punto los hijos generados no son soluciones(algunos nodos se repiten y otros no están)
def Factibilizar(solucion,problem):
  Nodos = list(problem.get_nodes())
  nodos_desaparecidos = list(set(Nodos) - set(solucion))
  #Recorremos todos los nodos, cuando haya uno que ya esté en la lista los cambiamos por uno de la lista de nodos_desaparecidos
  for i in range(len(solucion) ):
    if solucion[i] in solucion[:i]:
      #print("\tSe repite el",solucion[i] )
      #print("\tSe cambia en la posicion ",i , " " ,solucion[i] , " por ", nodos_desaparecidos[0] )
      solucion[i] = nodos_desaparecidos.pop(0) #Cambiamos el nodo y a la vez eliminamos el nodo usado de nodos_desaparecidos
  return solucion

#Funcion de mutación. Se eligen dos nodos y se intercambia. Se podrian añadir otros operaradores
# Se hace mutaciones mutacion% de las veces
def Mutar(solucion,mutacion):
    if random.random() < mutacion:
        sel1, sel2 = random.sample(range(1, len(solucion)), 2)
        solucion[sel1], solucion[sel2] = solucion[sel2], solucion[sel1]
    return solucion
        
#Funcion de seleccion de la población. Recibe como parametro una poblacion y
# devuelve una poblacion a la que se ha eliminado individuos poco aptos(fitness alto) y para mantener una poblacion estable de N individuos
#Se tiene en cuenta el porcentaje elitismo pasado como parametro
# Para los individuos que no son de la elite podríamos usar una selección de ruleta(proporcional a su fitness)
def Seleccionar(problem,poblacion, N, elitismo):
    poblacion_ordenada = sorted(
        [[distancia_total(solucion, problem), solucion] for solucion in poblacion],
        key=lambda x: x[0]
    )
    elite = [x[1] for x in poblacion_ordenada][:int(N * elitismo)]
    resto = random.sample(
        [x[1] for x in poblacion_ordenada][int(N * elitismo):],
        int(N * (1 - elitismo))
    )
    return elite + resto

# %%
#Funcion principal del algoritmo genetico
#######################################################3
def algoritmo_genetico(problem=problem,N=100,mutacion=.15,elitismo=.1,generaciones=100):
  # problem = datos del problema
  # N = Tamaño de la población
  # mutacion = probabilidad de una mutación
  # elitismo = porcion de la mejor poblacion a mantener
  # generaciones = nº de generaciones a generar para finalizar

  #Genera la poblacion inicial
    Nodos = list(problem.get_nodes())
    poblacion = generar_poblacion(Nodos, N)
    
    mejor_solucion, mejor_distancia = Evaluar_Poblacion(poblacion, problem)
    
    mejores_distancias = [mejor_distancia]
    
    for n in range(generaciones):
        poblacion = Cruzar(poblacion, mutacion, problem)
        poblacion = Seleccionar(problem, poblacion, N, elitismo)
        mejor_solucion, mejor_distancia = Evaluar_Poblacion(poblacion, problem)
    
        mejores_distancias.append(mejor_distancia)
        print(f"Generación {n+1}: Mejor distancia = {mejor_distancia}")
    
    return mejor_solucion, mejor_distancia

#1º intento  :2113
#sol = algoritmo_genetico(problem=problem,N=100,mutacion=.15,elitismo=.1,generaciones=200)

#2º intento. Aumentamos la poblacion:1654
#sol = algoritmo_genetico(problem=problem,N=500,mutacion=.15,elitismo=.1,generaciones=200)

#3º intento. Aumentamos las generaciones:2055
#sol = algoritmo_genetico(problem=problem,N=500,mutacion=.15,elitismo=.1,generaciones=250)

#4º intento. Aumentamos el elitismo: 1728
#sol = algoritmo_genetico(problem=problem,N=500,mutacion=.15,elitismo=.40,generaciones=250)

#5º intento. Aumentamos la mutacion : 1629 [0, 29, 9, 21, 40, 24, 39, 22, 38, 30, 28, 4, 18, 26, 5, 6, 32, 34, 33, 20, 35, 36, 31, 17, 37, 7, 8, 23, 41, 10, 25, 11, 12, 13, 19, 14, 16, 15, 1, 3, 2, 27]
sol, distancia = algoritmo_genetico(problem, N=500, mutacion=0.15, elitismo=0.4, generaciones=250)
print(f"Mejor solución encontrada: {sol} con una distancia de {distancia}")
# Out:
# Generación 1: Mejor distancia = 3944
# Generación 2: Mejor distancia = 3814
# Generación 3: Mejor distancia = 3568
# Generación 4: Mejor distancia = 3568
# Generación 5: Mejor distancia = 3507
# Generación 6: Mejor distancia = 3507
# Generación 7: Mejor distancia = 3430
# Generación 8: Mejor distancia = 3333
# Generación 9: Mejor distancia = 3280
# Generación 10: Mejor distancia = 3188
# Generación 11: Mejor distancia = 3188
# Generación 12: Mejor distancia = 3124
# Generación 13: Mejor distancia = 3115
# Generación 14: Mejor distancia = 3089
# Generación 15: Mejor distancia = 2965
# Generación 16: Mejor distancia = 2965
# Generación 17: Mejor distancia = 2876
# Generación 18: Mejor distancia = 2876
# Generación 19: Mejor distancia = 2876
# Generación 20: Mejor distancia = 2839
# Generación 21: Mejor distancia = 2839
# Generación 22: Mejor distancia = 2807
# Generación 23: Mejor distancia = 2793
# Generación 24: Mejor distancia = 2793
# Generación 25: Mejor distancia = 2793
# Generación 26: Mejor distancia = 2744
# Generación 27: Mejor distancia = 2744
# Generación 28: Mejor distancia = 2730
# Generación 29: Mejor distancia = 2724
# Generación 30: Mejor distancia = 2708
# Generación 31: Mejor distancia = 2661
# Generación 32: Mejor distancia = 2643
# Generación 33: Mejor distancia = 2622
# Generación 34: Mejor distancia = 2605
# Generación 35: Mejor distancia = 2557
# Generación 36: Mejor distancia = 2557
# Generación 37: Mejor distancia = 2557
# Generación 38: Mejor distancia = 2508
# Generación 39: Mejor distancia = 2508
# Generación 40: Mejor distancia = 2469
# Generación 41: Mejor distancia = 2401
# Generación 42: Mejor distancia = 2401
# Generación 43: Mejor distancia = 2401
# Generación 44: Mejor distancia = 2362
# Generación 45: Mejor distancia = 2362
# Generación 46: Mejor distancia = 2345
# Generación 47: Mejor distancia = 2310
# Generación 48: Mejor distancia = 2271
# Generación 49: Mejor distancia = 2271
# Generación 50: Mejor distancia = 2271
# Generación 51: Mejor distancia = 2219
# Generación 52: Mejor distancia = 2197
# Generación 53: Mejor distancia = 2197
# Generación 54: Mejor distancia = 2196
# Generación 55: Mejor distancia = 2144
# Generación 56: Mejor distancia = 2144
# Generación 57: Mejor distancia = 2144
# Generación 58: Mejor distancia = 2137
# Generación 59: Mejor distancia = 2137
# Generación 60: Mejor distancia = 2097
# Generación 61: Mejor distancia = 2097
# Generación 62: Mejor distancia = 2094
# Generación 63: Mejor distancia = 2074
# Generación 64: Mejor distancia = 2056
# Generación 65: Mejor distancia = 2047
# Generación 66: Mejor distancia = 2047
# Generación 67: Mejor distancia = 2047
# Generación 68: Mejor distancia = 2035
# Generación 69: Mejor distancia = 2035
# Generación 70: Mejor distancia = 2002
# Generación 71: Mejor distancia = 1993
# Generación 72: Mejor distancia = 1993
# Generación 73: Mejor distancia = 1952
# Generación 74: Mejor distancia = 1952
# Generación 75: Mejor distancia = 1952
# Generación 76: Mejor distancia = 1952
# Generación 77: Mejor distancia = 1915
# Generación 78: Mejor distancia = 1915
# Generación 79: Mejor distancia = 1894
# Generación 80: Mejor distancia = 1894
# Generación 81: Mejor distancia = 1894
# Generación 82: Mejor distancia = 1894
# Generación 83: Mejor distancia = 1894
# Generación 84: Mejor distancia = 1894
# Generación 85: Mejor distancia = 1866
# Generación 86: Mejor distancia = 1866
# Generación 87: Mejor distancia = 1866
# Generación 88: Mejor distancia = 1866
# Generación 89: Mejor distancia = 1866
# Generación 90: Mejor distancia = 1866
# Generación 91: Mejor distancia = 1866
# Generación 92: Mejor distancia = 1866
# Generación 93: Mejor distancia = 1866
# Generación 94: Mejor distancia = 1844
# Generación 95: Mejor distancia = 1844
# Generación 96: Mejor distancia = 1844
# Generación 97: Mejor distancia = 1844
# Generación 98: Mejor distancia = 1844
# Generación 99: Mejor distancia = 1844
# Generación 100: Mejor distancia = 1844
# Generación 101: Mejor distancia = 1844
# Generación 102: Mejor distancia = 1844
# Generación 103: Mejor distancia = 1844
# Generación 104: Mejor distancia = 1844
# Generación 105: Mejor distancia = 1840
# Generación 106: Mejor distancia = 1840
# Generación 107: Mejor distancia = 1840
# Generación 108: Mejor distancia = 1840
# Generación 109: Mejor distancia = 1830
# Generación 110: Mejor distancia = 1830
# Generación 111: Mejor distancia = 1829
# Generación 112: Mejor distancia = 1829
# Generación 113: Mejor distancia = 1826
# Generación 114: Mejor distancia = 1826
# Generación 115: Mejor distancia = 1826
# Generación 116: Mejor distancia = 1815
# Generación 117: Mejor distancia = 1815
# Generación 118: Mejor distancia = 1815
# Generación 119: Mejor distancia = 1815
# Generación 120: Mejor distancia = 1815
# Generación 121: Mejor distancia = 1815
# Generación 122: Mejor distancia = 1815
# Generación 123: Mejor distancia = 1815
# Generación 124: Mejor distancia = 1815
# Generación 125: Mejor distancia = 1815
# Generación 126: Mejor distancia = 1815
# Generación 127: Mejor distancia = 1815
# Generación 128: Mejor distancia = 1815
# Generación 129: Mejor distancia = 1815
# Generación 130: Mejor distancia = 1815
# Generación 131: Mejor distancia = 1815
# Generación 132: Mejor distancia = 1815
# Generación 133: Mejor distancia = 1815
# Generación 134: Mejor distancia = 1815
# Generación 135: Mejor distancia = 1815
# Generación 136: Mejor distancia = 1815
# Generación 137: Mejor distancia = 1815
# Generación 138: Mejor distancia = 1815
# Generación 139: Mejor distancia = 1815
# Generación 140: Mejor distancia = 1815
# Generación 141: Mejor distancia = 1815
# Generación 142: Mejor distancia = 1815
# Generación 143: Mejor distancia = 1815
# Generación 144: Mejor distancia = 1815
# Generación 145: Mejor distancia = 1815
# Generación 146: Mejor distancia = 1815
# Generación 147: Mejor distancia = 1815
# Generación 148: Mejor distancia = 1815
# Generación 149: Mejor distancia = 1815
# Generación 150: Mejor distancia = 1815
# Generación 151: Mejor distancia = 1815
# Generación 152: Mejor distancia = 1815
# Generación 153: Mejor distancia = 1815
# Generación 154: Mejor distancia = 1815
# Generación 155: Mejor distancia = 1815
# Generación 156: Mejor distancia = 1815
# Generación 157: Mejor distancia = 1815
# Generación 158: Mejor distancia = 1815
# Generación 159: Mejor distancia = 1815
# Generación 160: Mejor distancia = 1815
# Generación 161: Mejor distancia = 1815
# Generación 162: Mejor distancia = 1815
# Generación 163: Mejor distancia = 1815
# Generación 164: Mejor distancia = 1815
# Generación 165: Mejor distancia = 1815
# Generación 166: Mejor distancia = 1815
# Generación 167: Mejor distancia = 1815
# Generación 168: Mejor distancia = 1815
# Generación 169: Mejor distancia = 1815
# Generación 170: Mejor distancia = 1815
# Generación 171: Mejor distancia = 1815
# Generación 172: Mejor distancia = 1815
# Generación 173: Mejor distancia = 1815
# Generación 174: Mejor distancia = 1815
# Generación 175: Mejor distancia = 1815
# Generación 176: Mejor distancia = 1815
# Generación 177: Mejor distancia = 1815
# Generación 178: Mejor distancia = 1815
# Generación 179: Mejor distancia = 1815
# Generación 180: Mejor distancia = 1815
# Generación 181: Mejor distancia = 1815
# Generación 182: Mejor distancia = 1815
# Generación 183: Mejor distancia = 1815
# Generación 184: Mejor distancia = 1815
# Generación 185: Mejor distancia = 1815
# Generación 186: Mejor distancia = 1815
# Generación 187: Mejor distancia = 1815
# Generación 188: Mejor distancia = 1815
# Generación 189: Mejor distancia = 1815
# Generación 190: Mejor distancia = 1815
# Generación 191: Mejor distancia = 1815
# Generación 192: Mejor distancia = 1815
# Generación 193: Mejor distancia = 1815
# Generación 194: Mejor distancia = 1815
# Generación 195: Mejor distancia = 1815
# Generación 196: Mejor distancia = 1815
# Generación 197: Mejor distancia = 1815
# Generación 198: Mejor distancia = 1815
# Generación 199: Mejor distancia = 1815
# Generación 200: Mejor distancia = 1815
# Generación 201: Mejor distancia = 1815
# Generación 202: Mejor distancia = 1815
# Generación 203: Mejor distancia = 1815
# Generación 204: Mejor distancia = 1815
# Generación 205: Mejor distancia = 1815
# Generación 206: Mejor distancia = 1815
# Generación 207: Mejor distancia = 1815
# Generación 208: Mejor distancia = 1815
# Generación 209: Mejor distancia = 1815
# Generación 210: Mejor distancia = 1815
# Generación 211: Mejor distancia = 1815
# Generación 212: Mejor distancia = 1815
# Generación 213: Mejor distancia = 1815
# Generación 214: Mejor distancia = 1815
# Generación 215: Mejor distancia = 1815
# Generación 216: Mejor distancia = 1815
# Generación 217: Mejor distancia = 1815
# Generación 218: Mejor distancia = 1815
# Generación 219: Mejor distancia = 1815
# Generación 220: Mejor distancia = 1815
# Generación 221: Mejor distancia = 1815
# Generación 222: Mejor distancia = 1815
# Generación 223: Mejor distancia = 1815
# Generación 224: Mejor distancia = 1815
# Generación 225: Mejor distancia = 1815
# Generación 226: Mejor distancia = 1815
# Generación 227: Mejor distancia = 1815
# Generación 228: Mejor distancia = 1815
# Generación 229: Mejor distancia = 1815
# Generación 230: Mejor distancia = 1815
# Generación 231: Mejor distancia = 1815
# Generación 232: Mejor distancia = 1815
# Generación 233: Mejor distancia = 1815
# Generación 234: Mejor distancia = 1815
# Generación 235: Mejor distancia = 1815
# Generación 236: Mejor distancia = 1815
# Generación 237: Mejor distancia = 1815
# Generación 238: Mejor distancia = 1815
# Generación 239: Mejor distancia = 1815
# Generación 240: Mejor distancia = 1815
# Generación 241: Mejor distancia = 1815
# Generación 242: Mejor distancia = 1815
# Generación 243: Mejor distancia = 1815
# Generación 244: Mejor distancia = 1815
# Generación 245: Mejor distancia = 1815
# Generación 246: Mejor distancia = 1815
# Generación 247: Mejor distancia = 1815
# Generación 248: Mejor distancia = 1815
# Generación 249: Mejor distancia = 1815
# Generación 250: Mejor distancia = 1815
# Mejor solución encontrada: [0, 14, 16, 15, 7, 32, 8, 41, 23, 9, 21, 39, 22, 34, 20, 33, 38, 24, 40, 29, 30, 28, 27, 2, 3, 4, 5, 13, 19, 37, 17, 36, 35, 31, 10, 25, 11, 12, 18, 26, 6, 1] con una distancia de 1815
